# %%
# I have initially thought about using the function count. But after checking some resources, it seems that the function sort was easier.
def anagram_checker(word_a, word_b):
    word_a = word_a.lower()
    word_b = word_b.lower()

    word_a = sorted(word_a)
    word_b = sorted(word_b)

    #now we prompt a comparison 
    if word_a == word_b:
        return True
    else:
        return False

# I wasn't sure if the assignment aimed at having one full code or two. 
def anagram_checker(word_a, word_b, is_case_sensitive):
    if not is_case_sensitive:
        word_a = word_a.lower()
        word_b = word_b.lower()
    if len(word_a) != len(word_b): 
        return False
    sorted_a = sorted(word_a)
    sorted_b = sorted(word_b)
    if sorted_a == sorted_b:
        return True
    else:
        return False
